# %%
import os

lists = os.listdir('C:\SIST\Downloads')

# %%
for folder in lists:
# Out:
# ['01_Chrome',
#  '02_Font',
#  '03_JDK',
#  '04_EditPlus',
#  '05_Oracle11gXE',
#  '06_SqlDeveloper',
#  '07_배포_scott',
#  '08_배포_TBL_INSA',
#  '09_Eclipse',
#  '10_ojdbc6',
#  '11_ApacheTomcat',
#  '12_epf',
#  '13_image',
#  '14_WebApp21_관련자료',
#  '15_JSTL',
#  '16_jQuery',
#  '17_jQuery_학습내용정리',
#  '18_jQuery_관련자료',
#  '19_JSON 관련자료',
#  '20_Spring',
#  '21_Bootstrap',
#  '22_실습자료배포',
#  '23_mybatis',
#  '90_JAD',
#  '90_JAD.zip',
#  '91_VisualStudioCode',
#  '92_SourceTree',
#  '93_MongoDB_Compass',
#  '94_MongoDB',
#  '95_MySQL',
#  '96_atom editor',
#  '97_node_js',
#  '98_Eclipse_Neon',
#  '99_adobe_XD',
#  'stdCode.xml',
#  '■ 이클립스 단축키(열복사포함).txt',
#  '이클립스 단축키.docx',
#  '이클립스 단축키.pdf',
#  '이클립스 단축키.xlsx']

# %%
os.listdir('C:\SIST\Downloads\이클립스 단축키')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-9cb7ef7a000c> in <module>
# ----> 1 os.listdir('C:\SIST\Downloads\이클립스 단축키')
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'C:\\SIST\\Downloads\\이클립스 단축키'

# %%
temp = os.walk('C:\SIST\Downloads')

# %%
for paths, dirs, files in temp:
    print(paths)
    print(dirs)
    print(files)
    print('-----------------------------------')
# Out:
# C:\SIST\Downloads
# ['01_Chrome', '02_Font', '03_JDK', '04_EditPlus', '05_Oracle11gXE', '06_SqlDeveloper', '07_배포_scott', '08_배포_TBL_INSA', '09_Eclipse', '10_ojdbc6', '11_ApacheTomcat', '12_epf', '13_image', '14_WebApp21_관련자료', '15_JSTL', '16_jQuery', '17_jQuery_학습내용정리', '18_jQuery_관련자료', '19_JSON 관련자료', '20_Spring', '21_Bootstrap', '22_실습자료배포', '23_mybatis', '90_JAD', '91_VisualStudioCode', '92_SourceTree', '93_MongoDB_Compass', '94_MongoDB', '95_MySQL', '96_atom editor', '97_node_js', '98_Eclipse_Neon', '99_adobe_XD']
# ['90_JAD.zip', 'stdCode.xml', '■ 이클립스 단축키(열복사포함).txt', '이클립스 단축키.docx', '이클립스 단축키.pdf', '이클립스 단축키.xlsx']
# -----------------------------------
# C:\SIST\Downloads\01_Chrome
# []
# ['ChromeSetup.exe']
# -----------------------------------
# C:\SIST\Downloads\02_Font
# ['Handlee', 'Noto_Sans_KR']
# ['Handlee.zip', 'NanumGothicCoding-2.5.zip', 'Noto_Sans_KR.zip']
# -----------------------------------
# C:\SIST\Downloads\02_Font\Handlee
# []
# ...

# %%
def printFolder(path):
    for paths, dirs, files in os.walk(path):
        if len(dirs)>0:
            for dir1 in dirs:
                print('---', dir1, '---')
                printFolder(dir1)
        for file1 in files:
            print(file1)

# %%
printFolder('C:\SIST\Downloads')
# Out:
# --- 01_Chrome ---
# --- 02_Font ---
# --- 03_JDK ---
# --- 04_EditPlus ---
# --- 05_Oracle11gXE ---
# --- 06_SqlDeveloper ---
# --- 07_배포_scott ---
# --- 08_배포_TBL_INSA ---
# --- 09_Eclipse ---
# --- 10_ojdbc6 ---
# --- 11_ApacheTomcat ---
# --- 12_epf ---
# --- 13_image ---
# --- 14_WebApp21_관련자료 ---
# --- 15_JSTL ---
# --- 16_jQuery ---
# --- 17_jQuery_학습내용정리 ---
# --- 18_jQuery_관련자료 ---
# --- 19_JSON 관련자료 ---
# --- 20_Spring ---
# --- 21_Bootstrap ---
# --- 22_실습자료배포 ---
# --- 23_mybatis ---
# --- 90_JAD ---
# --- 91_VisualStudioCode ---
# --- 92_SourceTree ---
# --- 93_MongoDB_Compass ---
# --- 94_MongoDB ---
# --- 95_MySQL ---
# --- 96_atom editor ---
# --- 97_node_js ---
# --- 98_Eclipse_Neon ---
# --- 99_adobe_XD ---
# 90_JAD.zip
# stdCode.xml
# ■ 이클립스 단축키(열복사포함).txt
# 이클립스 단축키.docx
# 이클립스 단축키.pdf
# 이클립스 단축키.xlsx
# ChromeSetup.exe
# --- Handlee ---
# --- Noto_Sans_KR ---
# Handlee.zip
# NanumGothicCoding-2.5.zip
# Noto_Sans_KR.zip
# Handlee-Regular.ttf
# OFL.txt
# ...

# %%
import os

def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print('{}{}'.format(subindent, f))

# %%
list_files('C:\SIST\Downloads')
# Out:
# Downloads/
#     90_JAD.zip
#     stdCode.xml
#     ■ 이클립스 단축키(열복사포함).txt
#     이클립스 단축키.docx
#     이클립스 단축키.pdf
#     이클립스 단축키.xlsx
#     01_Chrome/
#         ChromeSetup.exe
#     02_Font/
#         Handlee.zip
#         NanumGothicCoding-2.5.zip
#         Noto_Sans_KR.zip
#         Handlee/
#             Handlee-Regular.ttf
#             OFL.txt
#         Noto_Sans_KR/
#             NotoSansKR-Black.otf
#             NotoSansKR-Bold.otf
#             NotoSansKR-Light.otf
#             NotoSansKR-Medium.otf
#             NotoSansKR-Regular.otf
#             NotoSansKR-Thin.otf
#             OFL.txt
#     03_JDK/
#         jdk-8u201-windows-x64.exe
#     04_EditPlus/
#         epp510_1828_64bit.exe
#     05_Oracle11gXE/
#         OracleXE112_Win64.zip
#     06_SqlDeveloper/
#         sqldeveloper-18.4.0-376.1900-no-jre.zip
#     07_배포_scott/
#         ■ scott(new).sql
#     08_배포_TBL_INSA/
#         TBL_INSA-1조_홍길동.sql
#     09_Eclipse/
# ...
