# %% [markdown]
# 저번 강의는 Binart Classification 이었다면<br>
# 이번 강의는 Multinomial Classification과 거기에 사용되는 Softmax Regression을 알아본다.
#
# ![softmax01.PNG](attachment:softmax01.PNG)
# 어제 강의를 위 처럼 요약해 볼 수 있다.<br>
# 저 네모네모한 도식을 잘 봐두자. 자주 나온다. 초록색 지렁이가 들어간 네모는 Sigmoid임.<br>
# Y는 실제 데이터, Y+hat 은 예측값을 나타내는 기호.
#
# 수학적으로 정확한 비유는 아니지만 지금까지 한 것들은
# ![softmax02.PNG](attachment:softmax02.PNG)
# 위 그림처럼 분류되는 데이터를 가르는 선을 학습 시키는 것임.
#
# Multinomial에서도 저 개념을 똑같이 사용한다.
# ![softmax03.PNG](attachment:softmax03.PNG)
# 근데 상식적으로 위처럼 하나의 선으로 여러개를 구분할 수 있을까? 당연히 아님. 그래서
# ![softmax04.PNG](attachment:softmax04.PNG)
# 그냥 여러 선 그으면 됨.
#
# 이건 개념적인 설명이고 구현은 어떻게?
# ![softmax05.PNG](attachment:softmax05.PNG)
# 이렇게 여러 줄을 쓸수도 있지만
# ![softmax06.PNG](attachment:softmax06.PNG)
# 행렬로 묶어야지.<br>
# 그런데 이렇게 나온 값은 Sigmoid가 안되어 있음.<br>
# 그냥 x1w1+x2w2+x3w3+...+xnwn 되어있는 값이니까.<br>
# 이걸 y-hat 들에 각각 Sigmoid를 씌워줄 수 있음.
#
# 하지만, 더 멋진 방법이 있다.
#
# 그게 바로 Softmax임.
# ![softmax07.PNG](attachment:softmax07.PNG)
# 위에서 한 결과를 위처럼 나타낼 수 있음<br>
# 결과인 Y벡터가 중구난방 여러 값이 나온것임.<br>
# 이를 Sigmoid 비슷하게 압축 시키는데, 보너스로 다 더하면 1로 만들어줌.
#
# ![softmax08.PNG](attachment:softmax08.PNG)
# 각각의 값들을 0~1로 압축 시키되<br>
# 각각의 값들의 합이 1이 되는 함수.<br>
# 그것이 바로 softmax임.
#
# 이렇게 되면 나온 값들을 확률로 볼 수 있음.
#
# ![softmax09.PNG](attachment:softmax09.PNG)
# 그다음 그중 'One-Hot Encoding'이라는걸 쓰면 확률 높은걸 1로 확정, 나머지를 0으로 보낼 수 있음.
#
# 여기까지가 Hypothesis 였음
#
# 그럼 이제 다음 단계는.. 비용함수!
#
# 결과적으로 말하자면 비용함수는 Cross-Entropy라는 함수를 사용한다.
#
#
# 으아 귀에 안들어온다. lec6-2 6분 50초에서 잠시 스탑.
# 내일 lec06-2, lab06-1,2 하고
#
# lec07-1,2 lab07-1,2 하자.
