# %%
# 여기선 분류를 알아볼꺼임.
# 그런데 지금까지 배운 Linear Regression으론 분류를 할 수 없음.
# 한정된 데이터에선 가능해도 범위가 달라지면 아예 다른 값들이 나오기 때문임
# 그래서 분류에서 사용하는 기본 함수는 Sigmoid 함수임.

# Linear Regression에서 기본이
# H(X) = XW + b 
# 였다면

# 분류의 기본인 Logistic Hypothesis 는
# H(X) = 1/(1+e**(-XW))
# 이거임. 이게 Sigmoid함수. 
# 쉽게말해 linear regression의 결과를 Sigmoid 함수에 넣어서 -1~1 범위로 줄이는 거임.

# 이렇게 가설을 바꿨으면 다음 문제는 
# 비용함수를 어떻게 처리할까이다. 

# Linear Regression의 비용함수를 그리면 깔끔한 2차함수가 나옴.
# 근데 Logistic Regression을 Linear Regression 하듯이 하면 변곡점이 여러개 생김.
# 전문적으로 말하자면 Non-Convex 함수가 되어버림. 로컬한 부분에서 멈출 수 있음.

# 그래서 cost 함수도 바꿔야 한다. 
# c(H(X), y) = (y)*(-log(H(X))) + (y-1)*(-log(1-H(x)))
# 이렇게 만들어줌. 직관적으로 설명하자면 Sigmoid의 분모인 지수함수를 풀어주는게 로그라는거임.

# 최종 비용함수는
# cost(W) = -1/m * 시그마((y)*(-log(H(X))) + (y-1)*(-log(1-H(x)))) 이정도가 되는거임. 

# 경사하강은 Linear Regression이랑 같음. 
# W = W - a*(비용함수 미분)

# %% [markdown]
# 여기서 배울 Logistic Classification은 정확도가 높아서 배우고 당장 활용해 볼 수 있다.
#
# 지금까지 수업을 다시 복기해보면<br>
# Hypothesis<br>
# Cost<br>
# Gradient Decent<br>
# 위 셋이 중요 개념이었음. 수식은 생략할게<br>
# Linear Regression에선 Cost함수가 Convex하기 때문에 Gradient Decent 법을 사용해서 Cost를 minimize 할 수 있었음.
#
# Classification도 기본적이 구조는 같음<br>
# 일단 이 강의에선 기본적인 Binary Classification을 해볼거임<br>
# 스팸 메일 차단, 페이스북 feed를 show할지 hide할지 정하는것, 사용패턴을 분석해 신용카드 절도 판별하는 것 같은 True, False로 나뉘어지는 것들에 이 Binary Classification을 사용함.
#
# 이미지를 보고 암이 있는지, 없는지 분석하는것도, 주식을 분석해서 up할지 down할지 예측하는 것도. Classification임.
#
# 하지만 여기선 쉬운 예제로 공부 시간에 따른 Pass, Fail을 예시로 공부해보자.
#
# 이걸 지난 강의까지 배운 Linear Regression을 이용해 풀어 본다면??
#
# ![classification1.PNG](attachment:classification1.PNG)
# 위 이미지 처럼 6개 데이터가 들어갔고 공부시간에 따라 1, 0이 나뉘어 졌음. <br>
# 그를 토대로 WX가 하나 만들어졌고 WX가 0.5 이상이면 1로 예측, 0.5미만이면 0으로 예측 할 수 있을 것 같음<br>
# 그리고 그를 토대로 합격을 결정짓는 공부시간 기준선을 예측할 수 있음.
# ![classification2.PNG](attachment:classification2.PNG)
# 그런데 공부를 엄청 많이 한 얘의 데이터가 들어왔음.<br>
# 당연히 합격했는데 이 공부를 엄청 한 얘의 데이터를 학습한 우리의 WX는 위 그림처럼 아래로 기울어지게 됨<br>
# 그런데 이 데이터가 그래프를 아래로 내려놓으니 합격 예상 공부시간을 더 높게 예측을 하게 됨<br>
# 사진에서 첫번째 hours 수직선에서 두번째 hours 수직선만큼 이동했고<br>
# 원래 합격해야될 얘를 불합격으로 예측하게 됨.
#
# 이게 Classification에서 Linear Regression을 못쓰는 문제임
#
# 그리고 Classification 하려면 값이 0~1 이 나와야 하는데<br>
# Linear Regression에선 0~1을 쉽게 벗어남.
#
# 그래서 Linear Regreesion을 압축 시키는 방법을 고안해냄.<br>
# Sigmoid라는 함수임 (Logistic Function 이라고도 부름)<br>
# ![sigmoid_function.png](attachment:sigmoid_function.png)
# ![sigmoid_function2.png](attachment:sigmoid_function2.png)
# 무엇을 넣든 1~0값인 나오는 함수임.이를
# g(Z) 라고 보통 부름
#
# 그래서 최종적인 Logistic Classification은
# ![logistic_function2.PNG](attachment:logistic_function2.PNG)
# 이렇게 된다.
#
# 그럼 이제 다음 챕터는 Cost Function을 만드는 것이다.<br>
# Linear Regression에서 Cost Function은 Convex해서 쉽게 minimize 값을 찾아 갈 수 있었음.
#
# 그런데 기존 Cost Function을 여기서 사용하면 아래와 같은 결과나 나타남.
# ![logistic_function_cost_function.PNG](attachment:logistic_function_cost_function.PNG)
# 대충 이런 모양으로
# ![logistic_function_cost_function3.PNG](attachment:logistic_function_cost_function3.PNG)
# 로컬한 minimize에서 멈출 수 있음
#
#
# 그래서 일단 결론적으로 말하면 아래 함수를 사용함
# ![logistic_function_cost_function4.PNG](attachment:logistic_function_cost_function4.PNG)
# 이 함수를 쓰면
# ![logistic_function_cost_function2.PNG](attachment:logistic_function_cost_function2.PNG)
# 이렇게 convex한 함수를 만들어 낼 수 있음.
#
# Linear Regression에서 썼던 Cost Function은 예측값과 실제값의 차이들을 제곱해서 평균내니까 그걸 최소화 하는 개념이었음
#
# 여기선 그래프를 보면서 잘 생각해봐라. 실제값이 1일때 를 먼저 생각해보자.<br>
# 실제값이 1일땐 H(X)가 1에 가까워야함. 근데<br>
# 위 비용함수 그래프를 역으로 생각해보면, 비용함수가 최소화 되는 방향이 H(X)가 1에 가까워 지는 것임<br>
# 그리고 H(X)가 정답인 1에서 멀어질수록 Cost가 무한대로 올라감
#
# 반대로 실제값이 0일땐 H(X)가 0에 가까워지는게 바람직한 예측임<br>
# 이번에도 그래프를 역으로 보자. 비용함수를 최소화하는 방향이 H(X)가 0으로 가는 방향임.<br>
# 여기도 역시 H(X)가 정답인 0에서 멀어지면 Cost가 무한대로 올라감
#
# 일단 이런식으로 이해하자. 사실 Linear Regression에서의 Cost Function보다 직관적으로 와 닿진 않지만.
#
# 근데 사실 Linear Regression의 Cost Function은 확률, 통계 할때 부터 접하던 개념이라 익숙해 진 것일 수도 있다고 생각함.
#
# 저 비용함수를 정리하면
# ![logistic_function_cost_function5.PNG](attachment:logistic_function_cost_function5.PNG)
# 이렇게 쓸 수 있다.
#
#
# 자, 이제 비용함수를 구했으니 다음 스텝은 비용을 최소화 하는 것이겠지.<br>
# 근데 Convex한 함수를 만들어 놨으니 전에 썼던 방법을 그대로 쓰면 된다.
# ![logistic_function_cost_function6.PNG](attachment:logistic_function_cost_function6.PNG)
# Logistic Classification의 Cost Function은 미분하려면 귀찮지만.. 컴퓨터가 알아서 해줄거임.
#
# 그리고 저 비용함수는 1개 건에 대한 비용이고 실제로 여러 데이터를 비용함수로 만들땐
# ![logistic_function_cost_function7.PNG](attachment:logistic_function_cost_function7.PNG)
# 요렇게 시그마 때려주면 된다

# %%
# lab05

# 데이터 셋
x_data = [[1,2],[2,3],[3,1],[4,3],[5,3],[6,2]]
y_data = [[0],[0],[0],[1],[1],[1]]

# 변수 - 이제부터 shape에 진짜 주의
W = tf.Variable(tf.random_normal([2,1]), name='weight')
b = tf.Variable(tf.random_normal([2,1]), name='bias')

# 가설
hypothesis = tf.sigmoid(tf.matmul(X,W)+b)

# 비용함수
cost = -tf.reduce_mean(Y*tf.log(hypothesis)+(1-Y)*tf.log(1-hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)

# 이 부분은 새로 추가되는 부분 - 예측결과를 1, 0으로 캐스팅하고
# 정확도를 계산하는 노드들
predicted = tf.cast(hypothesis>0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# 실행
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # 200개마다 로그 찍기
    for step in range(10001):
        cost_val, _ = sess.run([cost, train], feed_dict={X:x_data, Y:y_data})
        if step%200 == 0:
            print(step, cost_val)
            
    # 최종 예측결과 찍기 - 여기서 x, y 데이터를 왜 다시 주는지는 의문..
    h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict={X: x_data, Y:y_data})
    print("\nHypothesis: ", h, "\nCorrect(Y): ", c, "Accuracy: ",a)

# %%
# 여기선 실제 데이터를 이용해서 당뇨병 예측을 한번 해봄
# 각 값들이 뭔지는 교수님도 모름
# 데이터 불러오는 것만 하면 나머지는 동일함
import numpy as np

# 데이터 셋
xy = np.loadtxt('data-03-diabetes.csv', dtype=np.float32, delimiter=',')
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

# placeholder
X = tf.placeholder(tf.float32, shape=[None, 8])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# 변수
W = tf.Variable(tf.random_normal([8,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# 가설
hypothesis = tf.sigmoid(tf.matmul(X,W)+b)
# 비용
cost = -tf.reduce_mean(Y*tf.log(hypothesis)+(1-Y)*tf.log(1-hypothesis))
train = tf.train.GradientDescentOptimizer(learing_rate=0.01).minimize(cost)

# 예측값 캐스트 및 정확도 계산
predicted = tf.cast(hypothesis>0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# 실행
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    feed = {X: x_data, Y:y_data}
    
    for step in range(10001):
        sess.run(train, feed_dict=feed)
        if step%200==0:
            print(step, sess.run(cost, feed)dict=feed)
            
    h,c,a = sess.run([hypothesis, predicted, accuracy], feed_dict = feed)
    print("\nHypothesis: ", h)
    print("Correct(Y): ", c)
    print("Accuracy: ", a)
